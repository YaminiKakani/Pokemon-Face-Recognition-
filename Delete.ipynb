# %%
import os
import shutil
import tensorflow as tf
import pandas as pd
import seaborn as sns
import numpy as np
import pickle
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Model
from tensorflow.keras import layers, models  # Added models import
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K
from tensorflow.keras.applications import MobileNetV2
import random
import matplotlib.pyplot as plt
from PIL import Image
from tensorflow.keras.callbacks import TensorBoard

# %%
# Path to the main dataset folder
dataset_path = "/Users/rajendarbore/Desktop/Pokemon Image Data/PokemonImagesData"

# %%
# Iterate through each Pokémon subfolder
for pokemon in os.listdir(dataset_path):
    pokemon_path = os.path.join(dataset_path, pokemon)

    # Check if it's a directory
    if os.path.isdir(pokemon_path):
        # Count the number of image files
        num_images = len([f for f in os.listdir(pokemon_path) if f.lower().endswith(('.png', '.jpg', '.jpeg'))])

        # Delete folder if it has less than 50 images
        if num_images < 50:
            shutil.rmtree(pokemon_path)
            print(f"Deleted folder: {pokemon_path} (Had {num_images} images)")

print("Cleanup completed!")
# Out:
# Deleted folder: /Users/rajendarbore/Desktop/Pokemon Image Data/PokemonImagesData/Kadabra (Had 49 images)
# Deleted folder: /Users/rajendarbore/Desktop/Pokemon Image Data/PokemonImagesData/Alolan Sandslash (Had 41 images)
# Deleted folder: /Users/rajendarbore/Desktop/Pokemon Image Data/PokemonImagesData/Omanyte (Had 45 images)
# Deleted folder: /Users/rajendarbore/Desktop/Pokemon Image Data/PokemonImagesData/Shellder (Had 46 images)
# Deleted folder: /Users/rajendarbore/Desktop/Pokemon Image Data/PokemonImagesData/Bellsprout (Had 40 images)
# Deleted folder: /Users/rajendarbore/Desktop/Pokemon Image Data/PokemonImagesData/Eevee (Had 37 images)
# Deleted folder: /Users/rajendarbore/Desktop/Pokemon Image Data/PokemonImagesData/Hypno (Had 47 images)
# Deleted folder: /Users/rajendarbore/Desktop/Pokemon Image Data/PokemonImagesData/Seel (Had 48 images)
# Deleted folder: /Users/rajendarbore/Desktop/Pokemon Image Data/PokemonImagesData/Zubat (Had 40 images)
# ...
